# %%
import pandas as pd
df = pd.read_excel('book.xlsx', index_col=0)

# %%
df
# Out:
#                                           Source  \
# 名词误用                     在环游世界的旅程中，我们见闻了许多新奇的事物。
# 名词误用                            球员满场飞跑，技巧地控制着皮球。
# 动词误用                        交通比较发展的地方，会成为货物的集散地。
# 动词误用                         年青人的身心发展，特别值得家长的重视。
# 动词误用                             辛亥革命，觉醒了中国人的心声。
# 动词误用               在手术室里，护士正忙于协助医生、消毒仪器，以方便进行手术。
# 形容词误用                   经过数十小时的学习，我已经熟练了基本的驾驶技术。
# 形容词误用                      同一件货品，在中港两地，价钱悬殊了一大半。
# 形容词误用                   连场大雨，在街上走了很短的路，裤管上沾满了泥泞。
# 主语、谓语搭配不当                            两部直升机在空中飞驰。
# 主语、谓语搭配不当                   随著经济的发展，人们的生活水平大为改善。
# 主语、谓语搭配不当     春风一阵阵吹来，树枝摇曳着，月光、树影一起晃动起来，发出沙沙的响声。
# 动词、宾语搭配不当                   警方表示有信心扫除软性毒品的祸害和影响。
# 动词、宾语搭配不当                     学写诗歌，要注意提炼诗的语言和题材。
# 动词、宾语搭配不当                  千言万语都表达不了我们对老师的感激的情绪。
# 主语残缺                            经过这次讲课，对大家的启发很大。
# 主语残缺                  在通讯事业迅速发展的情况下，可以得到的资讯越来越多。
# 宾语残缺                      世界红十字会是致力拯救第三世界国家贫困儿童。
# ...

# %%
new_rows = [{'Source': '成熟的苹果落地，是由于它对地球引力的作用。', 'Truth': '成熟的苹果落地，是由于地球引力对它的作用。'}, 
            {'Source': '我们如果把这本书不认真读好，就谈不到读别的书了。', 'Truth': '我们如果不把这本书认真读好，就谈不到读别的书了。'},
            {'Source': '这个问题在群众中广泛引起了议论。', 'Truth': '这个问题在群众中引起了广泛议论。'},
            {'Source': '巴甫洛夫整天忙于做条件反射的实验，他总是把动物用绳子缚在实验室的架子上。', 'Truth': '巴甫洛夫整天忙于做条件反射的实验，他总是用绳子把动物缚在实验室的架子上。'},
            {'Source': '当时，许峰正在住院，听到有险情，带病走出医院，不顾医生的阻拦，投入到抗洪救灾工作中去。', 'Truth': '当时，许峰正在住院，听到有险情，不顾医生的阻拦，带病走出医院，投入到抗洪救灾工作中去。'}]
df = df.append(new_rows)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31372\1137769731.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_rows)

# %%
new_rows = [{'Source': '这办法既卫生，又方便，深受群众所喜爱。', 'Truth': '这办法既卫生，又方便，深受群众喜爱。'}, 
            {'Source': '我们要下决心，花大力气，争取在本世纪把我国的教育事业达到先进水平。', 'Truth': '我们要下决心，花大力气，争取在本世纪使我国的教育事业达到先进水平。'},
            {'Source': '其实，胡适先生英文文章也写了不少，连同这一百几十件信礼，都应该收集成书，供中外学者阅读之便。', 'Truth': '其实，胡适先生英文文章也写了不少，连同这一百几十件信礼，都应该收集成书，以便中外学者阅读'},
            {'Source': '当然，要搞好跨学科渗透和综合，并非易事，需要下一番功夫不可。', 'Truth': '当然，要搞好跨学科渗透和综合，并非易事，非下一番功夫不可。'},
            {'Source': '这届全运会会徽、吉祥物设计的应征者大多是以青年师生为主。', 'Truth': '这届全运会会徽、吉祥物设计的应征者以青年师生为主。'}]
df = df.append(new_rows)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_31372\4087517049.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_rows)

# %%
df
# Out:
#                                                    Source  \
# 名词误用                              在环游世界的旅程中，我们见闻了许多新奇的事物。
# 名词误用                                     球员满场飞跑，技巧地控制着皮球。
# 动词误用                                 交通比较发展的地方，会成为货物的集散地。
# 动词误用                                  年青人的身心发展，特别值得家长的重视。
# 动词误用                                      辛亥革命，觉醒了中国人的心声。
# 动词误用                        在手术室里，护士正忙于协助医生、消毒仪器，以方便进行手术。
# 形容词误用                            经过数十小时的学习，我已经熟练了基本的驾驶技术。
# 形容词误用                               同一件货品，在中港两地，价钱悬殊了一大半。
# 形容词误用                            连场大雨，在街上走了很短的路，裤管上沾满了泥泞。
# 主语、谓语搭配不当                                     两部直升机在空中飞驰。
# 主语、谓语搭配不当                            随著经济的发展，人们的生活水平大为改善。
# 主语、谓语搭配不当              春风一阵阵吹来，树枝摇曳着，月光、树影一起晃动起来，发出沙沙的响声。
# 动词、宾语搭配不当                            警方表示有信心扫除软性毒品的祸害和影响。
# 动词、宾语搭配不当                              学写诗歌，要注意提炼诗的语言和题材。
# 动词、宾语搭配不当                           千言万语都表达不了我们对老师的感激的情绪。
# ...

# %%
df.to_csv('book_.csv')

# %%
sentences = [
    "中国人的性情是总喜欢调和折中的，譬如你说，这屋子太暗，须在这里开一个窗，大家一定不允许的。但如果你主张拆掉屋顶他们就来调和，愿意开窗了。",
    "惟将终夜长开眼，报答平生未展眉",
    "我原以为，你身为汉朝老臣，来到阵前，面对两军将士，必有高论。没想到，竟说出如此粗鄙之语！",
    "人生当中成功只是一时的，失败却是主旋律，但是如何面对失败，却把人分成不同的样子，有的人会被失败击垮，有的人能够不断的爬起来继续向前，我想真正的成熟，应该不是追求完美，而是直面自己的缺憾，这才是生活的本质，罗曼罗兰说过，这个世界上只有一种真正的英雄主义，那就是认清生活的真相，并且仍然热爱它。难道向上攀爬的那条路不是比站在顶峰更让人热血澎湃吗？",
    "我在树上游泳。",
    "我在游泳池游泳。",
    "我游泳在游泳池。",
    "尤是为了,更佳大的,念,念,李是彼,更伟大的多,你只会用这种方法解决问题吗!",
]
import jieba
import time

from models import MaskedBert, MaskedAlbert

model = MaskedAlbert.from_pretrained("/home/baojunshan/data/pretrained_models/albert_base_zh")


for s in sentences:
    ppl = model.perplexity(
        x=" ".join(s),   # 每个字空格隔开或者输入一个list
        verbose=False,     # 是否显示详细的probability，default=False
        temperature=1.0,   # softmax的温度调节，default=1
        batch_size=100,    # 推理时的batch size，可根据cpu或gpu而定，default=100
    )
    print(f"ppl: {ppl:.5f} # {s}")

model.perplexity(sentences[-4], verbose=True)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\configuration_utils.py:614, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     612 try:
#     613     # Load from local folder or from cache or download from model Hub and cache
# --> 614     resolved_config_file = cached_file(
#     615         pretrained_model_name_or_path,
#     616         configuration_file,
#     617         cache_dir=cache_dir,
#     618         force_download=force_download,
#     619         proxies=proxies,
#     620         resume_download=resume_download,
#     621         local_files_only=local_files_only,
#     622         use_auth_token=use_auth_token,
#     623         user_agent=user_agent,
#     624         revision=revision,
# ...
